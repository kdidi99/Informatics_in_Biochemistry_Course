# %% [markdown]
# ## Chapter 5: Customization and Seaborn
# by Tobias Dorer

# %%
import numpy as np
total  = np.loadtxt("protein.csv", delimiter=",")
hydrop = np.loadtxt("hydrop.csv", delimiter=",")

hydrophobis = []
for i in range(len(hydrop[0])):
    hydrophobis.append([hydrop[0,i], hydrop[1,i]])

# first import the pandas library
import pandas as pd


# create a list of lists
coords = []
for i in range(len(total[0])):
    coords.append([total[0,i], total[1,i], [total[0,i], total[1,i]] in hydrophobis])
    #print([total[0,i], total[1,i]])

# creating the Pandas DataFrame
df = pd.DataFrame(coords, columns = ['x', 'y', 'Hydrophobic'])

# to display the DataFrame.
df
# Out:
#              x         y  Hydrophobic
# 0    -2.250900 -2.275181         True
# 1     1.548807  2.714416         True
# 2    -1.065641 -0.985024         True
# 3     0.306978  3.067951         True
# 4     2.154072  1.784351         True
# ...        ...       ...          ...
# 1988 -0.471345 -4.428122        False
# 1989 -3.021397  3.014261        False
# 1990 -1.509039 -1.673697        False
# 1991 -5.290165  5.515822        False
# 1992  1.180258  1.032073        False
#
# [1993 rows x 3 columns]

# %% [markdown]
# The cell above creates a pandas dataframe out of the data from the protein before, which you can see printed. Now try again to visualize the distribution of the hydrophobic amino acids in relation to the total amino acids, now you can use seaborn and be creative.
